# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/gdrive/MyDrive/vnpt/tt_da/huongdg/khoat9_sample.csv")
df
# Out:
#           id  ngay_khoa  khoa_lai  dau_so nap_t1   nap_t2   nap_t3   nap_t4  \
# 0      93d6e  9/29/2021     False    8491    NaN  50000.0      NaN      NaN
# 1      5e3e7  9/24/2021     False    8494    NaN      NaN      NaN      NaN
# 2      d589a  9/27/2021     False    8491    NaN      NaN      NaN      NaN
# 3      5d6b8  9/24/2021     False    8494    NaN  50000.0  50000.0  50000.0
# 4      b6d6c  9/27/2021     False    8481    NaN      NaN      NaN      NaN
# ...      ...        ...       ...     ...    ...      ...      ...      ...
# 20073  50f78  9/27/2021     False    8491    NaN      NaN      NaN      NaN
# 20074  63ef8  9/29/2021     False    8494    NaN      NaN      NaN  50000.0
# 20075  fd8ed  9/29/2021     False    8482    NaN      NaN      NaN      NaN
# 20076  0f0f2  9/29/2021     False    8491    NaN      NaN      NaN      NaN
# 20077  e8d38  9/20/2021     False    8494    NaN   1000.0      NaN      NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20078 entries, 0 to 20077
# Data columns (total 55 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   20078 non-null  object
#  1   ngay_khoa            20078 non-null  object
#  2   khoa_lai             20078 non-null  bool
#  3   dau_so               20078 non-null  int64
#  4   nap_t1               213 non-null    object
#  5   nap_t2               2338 non-null   object
#  6   nap_t3               3548 non-null   object
#  7   nap_t4               3804 non-null   object
#  8   nap_t5               3508 non-null   object
#  9   nhan_tien            39 non-null     float64
#  10  ls_utn               105 non-null    float64
#  11  ls_udv               85 non-null     float64
#  12  ls_moi_utn           307 non-null    float64
#  13  truoc_goi_matphi     3186 non-null   float64
#  14  truoc_sms_matphi     1173 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['id', 'ngay_khoa', 'khoa_lai', 'dau_so', 'nap_t1', 'nap_t2', 'nap_t3',
#        'nap_t4', 'nap_t5', 'nhan_tien', 'ls_utn', 'ls_udv', 'ls_moi_utn',
#        'truoc_goi_matphi', 'truoc_sms_matphi', 'sau_goi_matphi',
#        'sau_sms_matphi', 'truoc_dk_goi', 'truoc_ds_goi', 'sau_dk_goi',
#        'sau_ds_goi', 'truoc_luuluong_data', 'sau_luuluong_data',
#        'truoc_luuluong_goi', 'sau_luuluong_goi', 'truoc_luuluong_sms',
#        'sau_luuluong_sms', 'sau_sua_thongtin', 'apru_1', 'apru_2', 'apru_3',
#        'apru_4', 'apru_5', 'call_1', 'call_2', 'call_3', 'call_4', 'call_5',
#        'data_1', 'data_2', 'data_3', 'data_4', 'data_5', 'goi_coban',
#        'ngay_kich_hoat', 'tuoi_sim', 'sodu_ngaykhoa', 'ngay_chuyen_60',
#        'trangthai_60', 'ngay_nap_tien_60', 'gia_tri_nap_60', 'ngay_mo_60',
#        '2simslot', 'truoc_matphi_v2'],
#       dtype='object')

# %%
df['quay_lai'] = (df.ngay_mo_60 > 0).astype(int)

# %%
df.groupby('goi_coban').agg({'id' : 'count'}).sort_values(by = 'id', ascending = False).plot(kind = 'pie', y = 'id', figsize = (10,10))

# %%
tk = df.groupby('goi_coban').agg({'id' : 'count'}).sort_values(by = 'id', ascending = False)

# %%
plt.figure(figsize=(10,10))
plt.pie(tk.id,labels = tk.index,autopct='%1.2f%%')
plt.show()

# %%
plt.figure(figsize=(30,10))
a = sns.countplot(x = 'goi_coban', hue = 'quay_lai' , data = df)
a.set_yscale("log")
# a.get_xticklabels().set_rotation(45)

# %% [markdown]
# **Biều đồ abc**
# - có đặc điểm 1

# %%
fig , ax = plt.subplots(2,1, figsize=(30,10))
ax[1].pie(tk.id,labels = tk.index,autopct='%1.2f%%')
sns.countplot(x = 'goi_coban', hue = 'quay_lai' , data = df, ax = ax[0])
ax[0].set_yscale("log")

# %% [markdown]
# - gì đó

# %%
df['tong_nap_t5'] = df.nap_t5.apply(lambda x: sum(map(float, str(x).split(",")))).fillna(0)
df['tong_nap_t4'] = df.nap_t4.apply(lambda x: sum(map(float, str(x).split(",")))).fillna(0)
df['tong_nap_t3'] = df.nap_t3.apply(lambda x: sum(map(float, str(x).split(",")))).fillna(0)
df['tong_nap_t2'] = df.nap_t2.apply(lambda x: sum(map(float, str(x).split(",")))).fillna(0)
df['tong_nap_t1'] = df.nap_t1.apply(lambda x: sum(map(float, str(x).split(",")))).fillna(0)
# df[['tong_nap_t5', 'nap_t5']]

# %%
tk = df[['tong_nap_t{}'.format(i) for i in range(1, 6)]].describe()
tk
# Out:
#          tong_nap_t1    tong_nap_t2   tong_nap_t3   tong_nap_t4
# count   20078.000000   20078.000000  2.007800e+04  2.007800e+04
# mean      768.602450    4965.135970  1.028275e+04  1.178708e+04
# std     10814.977391   27525.502984  4.749042e+04  5.779031e+04
# min         0.000000       0.000000  0.000000e+00  0.000000e+00
# 25%         0.000000       0.000000  0.000000e+00  0.000000e+00
# 50%         0.000000       0.000000  0.000000e+00  0.000000e+00
# 75%         0.000000       0.000000  0.000000e+00  0.000000e+00
# max    400000.000000  920000.000000  2.600000e+06  3.040000e+06

# %%
plt.plot(tk.columns[::-1], tk.loc['mean'][::-1])

# %% [markdown]
# - Trung bình nạp giảm và số lượng nạp giảm ....

# %%
df['sl_nap_t5'] = df.nap_t5.apply(lambda x: len( str(x).split(","))).fillna(0)
df['sl_nap_t4'] = df.nap_t4.apply(lambda x: len( str(x).split(","))).fillna(0)
df['sl_nap_t3'] = df.nap_t3.apply(lambda x: len( str(x).split(","))).fillna(0)
df['sl_nap_t2'] = df.nap_t2.apply(lambda x: len( str(x).split(","))).fillna(0)
df['sl_nap_t1'] = df.nap_t1.apply(lambda x: len( str(x).split(","))).fillna(0)

# %%
tk = df[['sl_nap_t{}'.format(i) for i in range(1, 6)]].describe()
tk
# Out:
#           sl_nap_t1     sl_nap_t2     sl_nap_t3     sl_nap_t4     sl_nap_t5
# count  20078.000000  20078.000000  20078.000000  20078.000000  20078.000000
# mean       1.008268      1.065295      1.149417      1.185775      1.185975
# std        0.154401      0.468641      0.878190      1.194762      1.156128
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      1.000000      1.000000      1.000000      1.000000
# 50%        1.000000      1.000000      1.000000      1.000000      1.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max       10.000000     16.000000     30.000000     57.000000     63.000000
